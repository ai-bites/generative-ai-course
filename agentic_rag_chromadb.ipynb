# %% [markdown]
# # Setup

# %% [markdown]
# ## Install Required Libraries

# %%
# !pip install pandas
# !pip install langchain_community
# !pip install langchain-tavily
# !pip install seaborn
# !pip install python-dotenv
# !pip install openai
# !pip install sentence-transformers
# !pip install chromadb
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
# Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]━━━━━━━━━━━ 2/3 [pandas]
# Successfully installed numpy-2.3.5 pandas-2.3.3 pytz-2025.2
# Collecting langchain_community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=1.0.1 (from langchain_community)
#   Downloading langchain_core-1.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Using cached langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.45-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain_community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Using cached aiohttp-3.13.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_community)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Using cached pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain_community)
#   Downloading langsmith-0.4.58-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain_community) (2.3.5)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached frozenlist-1.8.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached multidict-6.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached propcache-0.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached yarl-1.22.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (75 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.1 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached orjson-3.11.5-cp312-cp312-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached zstandard-0.25.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.0)
# Requirement already satisfied: certifi in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached aiohttp-3.13.2-cp312-cp312-macosx_11_0_arm64.whl (491 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
# Downloading langchain_core-1.1.3-py3-none-any.whl (475 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading langsmith-0.4.58-py3-none-any.whl (412 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.7.0-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
# Using cached pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading sqlalchemy-2.0.45-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.1 MB/s  0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (603 kB)
# Using cached yarl-1.22.0-cp312-cp312-macosx_11_0_arm64.whl (94 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached frozenlist-1.8.0-cp312-cp312-macosx_11_0_arm64.whl (50 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached orjson-3.11.5-cp312-cp312-macosx_15_0_arm64.whl (129 kB)
# Using cached propcache-0.4.1-cp312-cp312-macosx_11_0_arm64.whl (47 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached zstandard-0.25.0-cp312-cp312-macosx_11_0_arm64.whl (640 kB)
# Installing collected packages: zstandard, uuid-utils, typing-inspection, tenacity, SQLAlchemy, python-dotenv, pydantic-core, propcache, orjson, mypy-extensions, multidict, marshmallow, jsonpatch, httpx-sse, frozenlist, annotated-types, aiohappyeyeballs, yarl, typing-inspect, requests-toolbelt, pydantic, aiosignal, pydantic-settings, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-classic, langchain_community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30/30 [langchain_community] 29/30 [langchain_community]
# Successfully installed SQLAlchemy-2.0.45 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 annotated-types-0.7.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 jsonpatch-1.33 langchain-classic-1.0.0 langchain-core-1.1.3 langchain-text-splitters-1.0.0 langchain_community-0.4.1 langsmith-0.4.58 marshmallow-3.26.1 multidict-6.7.0 mypy-extensions-1.1.0 orjson-3.11.5 propcache-0.4.1 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-settings-2.12.0 python-dotenv-1.2.1 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspect-0.9.0 typing-inspection-0.4.2 uuid-utils-0.12.0 yarl-1.22.0 zstandard-0.25.0
# Collecting langchain-tavily
#   Using cached langchain_tavily-0.2.13-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-tavily) (3.13.2)
# Collecting langchain<2.0.0,>=0.3.20 (from langchain-tavily)
#   Using cached langchain-1.1.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.15 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-tavily) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-tavily) (2.32.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.22.0)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain<2.0.0,>=0.3.20->langchain-tavily)
#   Using cached langgraph-1.0.4-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain<2.0.0,>=0.3.20->langchain-tavily) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.4.58)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (3.0.0)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily)
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily)
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily)
#   Downloading langgraph_sdk-0.2.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily)
#   Using cached xxhash-3.6.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily)
#   Using cached ormsgpack-1.12.0-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.25.0)
# Requirement already satisfied: anyio in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily) (4.12.0)
# Requirement already satisfied: certifi in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily) (1.0.9)
# Requirement already satisfied: idna in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.6.1)
# Using cached langchain_tavily-0.2.13-py3-none-any.whl (26 kB)
# Using cached langchain-1.1.3-py3-none-any.whl (102 kB)
# Using cached langgraph-1.0.4-py3-none-any.whl (157 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.2.15-py3-none-any.whl (66 kB)
# Using cached ormsgpack-1.12.0-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (369 kB)
# Using cached xxhash-3.6.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Installing collected packages: xxhash, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain, langchain-tavily
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [langchain-tavily]7/8 [langchain-tavily]
# Successfully installed langchain-1.1.3 langchain-tavily-0.2.13 langgraph-1.0.4 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.2.15 ormsgpack-1.12.0 xxhash-3.6.0
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.10.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached fonttools-4.61.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (113 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.4.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-12.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.7-cp312-cp312-macosx_11_0_arm64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.0-cp312-cp312-macosx_10_13_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.9-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
# Using cached pillow-12.0.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [seaborn]━━━ 7/8 [seaborn]ib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.0 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5 seaborn-0.13.2
# Requirement already satisfied: python-dotenv in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (1.2.1)
# Collecting openai
#   Using cached openai-2.9.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from openai) (4.12.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Using cached jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from openai) (2.12.5)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Using cached openai-2.9.0-py3-none-any.whl (1.0 MB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (319 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: tqdm, sniffio, jiter, distro, openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [openai]━━━━ 4/5 [openai]
# Successfully installed distro-1.9.0 jiter-0.12.0 openai-2.9.0 sniffio-1.3.1 tqdm-4.67.1
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: tqdm in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from sentence-transformers) (4.67.1)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.9.1-cp312-none-macosx_11_0_arm64.whl.metadata (30 kB)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.8.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting scipy (from sentence-transformers)
#   Using cached scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-1.2.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from sentence-transformers) (4.15.0)
# Collecting filelock (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: setuptools in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.12)
# Collecting joblib>=1.3.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->sentence-transformers)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Using cached regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl (288 kB)
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Using cached torch-2.9.1-cp312-none-macosx_11_0_arm64.whl (74.5 MB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-macosx_12_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 17.5 MB/s  0:00:008.5 MB/s eta 0:00:01:01
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl (20.9 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: mpmath, threadpoolctl, sympy, scipy, safetensors, regex, networkx, joblib, hf-xet, fsspec, filelock, torch, scikit-learn, huggingface-hub, tokenizers, transformers, sentence-transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [sentence-transformers]16/17 [sentence-transformers]
# Successfully installed filelock-3.20.0 fsspec-2025.12.0 hf-xet-1.2.0 huggingface-hub-0.36.0 joblib-1.5.2 mpmath-1.3.0 networkx-3.6.1 regex-2025.11.3 safetensors-0.7.0 scikit-learn-1.8.0 scipy-1.16.3 sentence-transformers-5.1.2 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.1 torch-2.9.1 transformers-4.57.3
# Collecting chromadb
#   Downloading chromadb-1.3.6-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.2 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=1.9 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (2.12.5)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Using cached pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.22.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (2.3.5)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Using cached posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.23.2-cp312-cp312-macosx_13_0_arm64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.39.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.39.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.39.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (0.22.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.76.0-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: sympy in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.39.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.39.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.39.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.60b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.60b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Collecting click>=8.0.0 (from typer>=0.9.0->chromadb)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.7.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-1.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ssankar/miniconda3/envs/ar/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.3.6-cp39-abi3-macosx_11_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 14.3 MB/s  0:00:014.0 MB/s eta 0:00:0101
# Using cached posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
# Using cached build-1.3.0-py3-none-any.whl (23 kB)
# Using cached grpcio-1.76.0-cp312-cp312-macosx_11_0_universal2.whl (11.8 MB)
# Using cached kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Using cached google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Using cached cachetools-6.2.2-py3-none-any.whl (11 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached mmh3-5.2.0-cp312-cp312-macosx_11_0_arm64.whl (40 kB)
# Using cached onnxruntime-1.23.2-cp312-cp312-macosx_13_0_arm64.whl (17.2 MB)
# Using cached opentelemetry_api-1.39.0-py3-none-any.whl (66 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.39.0-py3-none-any.whl (19 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.39.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.39.0-py3-none-any.whl (72 kB)
# Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached opentelemetry_sdk-1.39.0-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b0-py3-none-any.whl (219 kB)
# Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl (31 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached typer-0.20.0-py3-none-any.whl (47 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Using cached httptools-0.7.1-cp312-cp312-macosx_11_0_arm64.whl (110 kB)
# Using cached uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl (1.4 MB)
# Using cached watchfiles-1.1.1-cp312-cp312-macosx_11_0_arm64.whl (391 kB)
# Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websockets, uvloop, urllib3, shellingham, pyproject_hooks, pybase64, pyasn1, protobuf, overrides, oauthlib, mmh3, mdurl, importlib-resources, humanfriendly, httptools, grpcio, click, cachetools, bcrypt, backoff, watchfiles, uvicorn, rsa, pyasn1-modules, opentelemetry-proto, markdown-it-py, importlib-metadata, googleapis-common-protos, coloredlogs, build, rich, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, typer, opentelemetry-semantic-conventions, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.6.1
#     Uninstalling urllib3-2.6.1:
#       Successfully uninstalled urllib3-2.6.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47/47 [chromadb] [chromadb]m [opentelemetry-exporter-otlp-proto-grpc]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-core 2.4.3 requires google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6, which is not installed.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, which is not installed.
# google-cloud-bigquery 3.35.1 requires google-api-core[grpc]<3.0.0,>=2.11.1, which is not installed.
# google-cloud-resource-manager 1.14.2 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1, which is not installed.
# google-cloud-resource-manager 1.14.2 requires proto-plus<2.0.0,>=1.22.3, which is not installed.
# Successfully installed backoff-2.2.1 bcrypt-5.0.0 build-1.3.0 cachetools-6.2.2 chromadb-1.3.6 click-8.3.1 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.9.23 google-auth-2.43.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 httptools-0.7.1 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 kubernetes-34.1.0 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.23.2 opentelemetry-api-1.39.0 opentelemetry-exporter-otlp-proto-common-1.39.0 opentelemetry-exporter-otlp-proto-grpc-1.39.0 opentelemetry-proto-1.39.0 opentelemetry-sdk-1.39.0 opentelemetry-semantic-conventions-0.60b0 overrides-7.7.0 posthog-5.4.0 protobuf-6.33.2 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.3 pypika-0.48.9 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 rich-14.2.0 rsa-4.9.1 shellingham-1.5.4 typer-0.20.0 urllib3-2.3.0 uvicorn-0.38.0 uvloop-0.22.1 watchfiles-1.1.1 websockets-15.0.1 zipp-3.23.0

# %% [markdown]
# ## All Imports

# %%
import pandas as pd
import numpy as np
import json
import re
from typing import List, Dict, Any, Tuple, Literal, TypedDict
from sentence_transformers import SentenceTransformer
from openai import OpenAI
import time
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from dotenv import load_dotenv
import openai
import os

# %% [markdown]
# ## API Keys

# %%
load_dotenv()

openai_api_key = os.getenv("OPEN_AI_KEY")
tavily_api_key = os.getenv("TAVILY_API_KEY")

# %% [markdown]
# ## Setup the Datasets

# %%
df_qa = pd.read_csv("./data/medical_qna_dataset.csv")
df_qa = df_qa.sample(500, random_state=0).reset_index(drop=True)
df_qa.head()
# Out:
#              qtype                                           Question  \
# 0        frequency  How many people are affected by X-linked chond...
# 1        treatment     What are the treatments for Kawasaki disease ?
# 2  genetic changes  What are the genetic changes related to Ellis-...
# 3         symptoms  What are the symptoms of Renal dysplasia-limb ...
# 4      information                    What is (are) Fraser syndrome ?
#
#                                               Answer
# 0  The prevalence of X-linked chondrodysplasia pu...
# 1  These resources address the diagnosis or manag...
# 2  Ellis-van Creveld syndrome can be caused by mu...
# 3  What are the signs and symptoms of Renal dyspl...
# 4  Fraser syndrome is a rare disorder that affect...

# %%
df_qa['combined_text'] = (
    "Question: " + df_qa['Question'].astype(str) + '. ' + 
    "Answer: " + df_qa['Answer'].astype(str) + '. ' + 
    "Type: " + df_qa['qtype'].astype(str) + '. '
)
df_qa.head()
# Out:
#              qtype                                           Question  \
# 0        frequency  How many people are affected by X-linked chond...
# 1        treatment     What are the treatments for Kawasaki disease ?
# 2  genetic changes  What are the genetic changes related to Ellis-...
# 3         symptoms  What are the symptoms of Renal dysplasia-limb ...
# 4      information                    What is (are) Fraser syndrome ?
#
#                                               Answer  \
# 0  The prevalence of X-linked chondrodysplasia pu...
# 1  These resources address the diagnosis or manag...
# 2  Ellis-van Creveld syndrome can be caused by mu...
# 3  What are the signs and symptoms of Renal dyspl...
# 4  Fraser syndrome is a rare disorder that affect...
#
#                                        combined_text
# 0  Question: How many people are affected by X-li...
# 1  Question: What are the treatments for Kawasaki...
# 2  Question: What are the genetic changes related...
# 3  Question: What are the symptoms of Renal dyspl...
# 4  Question: What is (are) Fraser syndrome ?. Ans...

# %%
df_md = pd.read_csv('./data/medical_device_manuals_dataset.csv')
df_md = df_md.sample(500, random_state=0).reset_index(drop=True)
df_md.head()
# Out:
#             Device_Name Model_Number       Manufacturer Manual_Version  \
# 0  Electrosurgical Unit   Model 1606      Zimmer Biomet      2023-04-Z
# 1      Dialysis Machine       X-6538      3M Healthcare           v2.8
# 2            Ventilator       SON230             Sonova     Version 13
# 3      Dialysis Machine       Max787  Boston Scientific           v4.7
# 4  Electrosurgical Unit      Plus691             Abbott      2020-03-Q
#
#   Publication_Date Device_Class Regulatory_Approval_ID Patient_Population  \
# 0       2018-04-28    Class IIb             MDR-847127                All
# 1       2018-04-03      Class I             MDR-416480        Adult (>65)
# 2       2022-02-24    Class III              BLA670706        Adult (>65)
# 3       2016-05-08     Class II              BLA131698           Neonatal
# 4       2015-01-30    Class III                H127393          Pediatric
#
#                                  Indications_for_Use  \
# 0  Used for thermal therapy guidance in oncology ...
# 1  Used for post-operative chemotherapy managemen...
# 2  Indicated for real-time temperature assessment...
# 3  Intended for sterilization guidance during min...
# 4  Intended for life support evaluation in rehabi...
#
#                                    Contraindications  \
# 0  Contraindicated in presence of radio frequenci...
# 1                                                NaN
# 2  Do not use during general anesthesia administr...
# 3  Not recommended during pregnancy, lactation, o...
# 4  Contraindicated in patients with severe diabet...
#
#        Sterilization_Method  Number_of_Warnings  Number_of_Cautions  \
# 0  Hydrogen Peroxide Plasma                  10                  15
# 1         Gamma Irradiation                   8                  11
# 2            Pre-Sterilized                  18                  28
# 3                       NaN                  10                  15
# 4        Single-Use Sterile                  13                  17
#
#    Device_Lifetime_Years  Device_Weight_kg  Max_Operating_Temperature_C
# 0                   15.0              6.71                         27.0
# 1                   11.0               NaN                         17.0
# 2                   11.0            149.42                         25.0
# 3                   15.0             20.96                         20.0
# 4                    8.0              7.75                         31.0

# %%
df_md['combined_text'] = (
    "Device Name: " + df_md['Device_Name'].astype(str) + ". " +
    "Model: " + df_md['Model_Number'].astype(str) + ". " +
    "Manufacturer: " + df_md['Manufacturer'].astype(str) + ". " +
    "Indications: " + df_md['Indications_for_Use'].astype(str) + ". " +
    "Contraindications: " + df_md['Contraindications'].fillna('None').astype(str)
)
df_md.head()
# Out:
#             Device_Name Model_Number       Manufacturer Manual_Version  \
# 0  Electrosurgical Unit   Model 1606      Zimmer Biomet      2023-04-Z
# 1      Dialysis Machine       X-6538      3M Healthcare           v2.8
# 2            Ventilator       SON230             Sonova     Version 13
# 3      Dialysis Machine       Max787  Boston Scientific           v4.7
# 4  Electrosurgical Unit      Plus691             Abbott      2020-03-Q
#
#   Publication_Date Device_Class Regulatory_Approval_ID Patient_Population  \
# 0       2018-04-28    Class IIb             MDR-847127                All
# 1       2018-04-03      Class I             MDR-416480        Adult (>65)
# 2       2022-02-24    Class III              BLA670706        Adult (>65)
# 3       2016-05-08     Class II              BLA131698           Neonatal
# 4       2015-01-30    Class III                H127393          Pediatric
#
#                                  Indications_for_Use  \
# 0  Used for thermal therapy guidance in oncology ...
# 1  Used for post-operative chemotherapy managemen...
# 2  Indicated for real-time temperature assessment...
# 3  Intended for sterilization guidance during min...
# 4  Intended for life support evaluation in rehabi...
#
#                                    Contraindications  \
# 0  Contraindicated in presence of radio frequenci...
# 1                                                NaN
# 2  Do not use during general anesthesia administr...
# 3  Not recommended during pregnancy, lactation, o...
# 4  Contraindicated in patients with severe diabet...
#
#        Sterilization_Method  Number_of_Warnings  Number_of_Cautions  \
# 0  Hydrogen Peroxide Plasma                  10                  15
# 1         Gamma Irradiation                   8                  11
# 2            Pre-Sterilized                  18                  28
# 3                       NaN                  10                  15
# 4        Single-Use Sterile                  13                  17
#
#    Device_Lifetime_Years  Device_Weight_kg  Max_Operating_Temperature_C  \
# 0                   15.0              6.71                         27.0
# 1                   11.0               NaN                         17.0
# 2                   11.0            149.42                         25.0
# 3                   15.0             20.96                         20.0
# 4                    8.0              7.75                         31.0
#
#                                        combined_text
# 0  Device Name: Electrosurgical Unit. Model: Mode...
# 1  Device Name: Dialysis Machine. Model: X-6538. ...
# 2  Device Name: Ventilator. Model: SON230. Manufa...
# 3  Device Name: Dialysis Machine. Model: Max787. ...
# 4  Device Name: Electrosurgical Unit. Model: Plus...

# %% [markdown]
# # Setup Chroma DB

# %%
import chromadb

client = chromadb.PersistentClient(path='./chroma_db')

# %%
collection1 = client.get_or_create_collection(name='medical_qna')

# %%
collection1.add(
    documents=df_qa['combined_text'].tolist(),
    metadatas = df_qa.to_dict(orient='records'),
    ids=df_qa.index.astype(str).tolist()
)

# %%
collection2 = client.get_or_create_collection(name='medical_device_manual')

# %%
collection2.add(
    documents=df_md['combined_text'].tolist(),
    metadatas=df_md.to_dict(orient="records"),
    ids=df_md.index.astype(str).tolist(),
)

# %%
query = "what are the devices relevant to surgery"

results = collection2.query(query_texts=[query], n_results=3)
print(results)
# Out:
# {'ids': [['403', '142', '82']], 'embeddings': None, 'documents': [['Device Name: Orthopedic Implant. Model: Model 4592. Manufacturer: Intuitive Surgical. Indications: Used for post-operative thermal therapy management in hospital recovery units.. Contraindications: Avoid use if patient has coagulopathy or is receiving iodine compounds.', 'Device Name: Surgical Robot. Model: BIO146. Manufacturer: BioMérieux. Indications: Used for therapeutic drug delivery in neonatal patients requiring wound debridement.. Contraindications: Avoid use in patients with mesh implants or mesh implants. Not suitable for infectious disease isolation.', 'Device Name: Anesthesia Machine. Model: C-1766. Manufacturer: Edwards Lifesciences. Indications: Used for intraoperative sterilization monitoring during complex oncological surgeries.. Contraindications: Avoid use in patients with active hepatic dysfunction or compromised respiratory function.']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'Device_Name': 'Orthopedic Implant', 'Number_of_Cautions': 12, 'Model_Number': 'Model 4592', 'Manufacturer': 'Intuitive Surgical', 'combined_text': 'Device Name: Orthopedic Implant. Model: Model 4592. Manufacturer: Intuitive Surgical. Indications: Used for post-operative thermal therapy management in hospital recovery units.. Contraindications: Avoid use if patient has coagulopathy or is receiving iodine compounds.', 'Sterilization_Method': 'Dry Heat', 'Number_of_Warnings': 8, 'Indications_for_Use': 'Used for post-operative thermal therapy management in hospital recovery units.', 'Publication_Date': '2023-04-14', 'Device_Weight_kg': 0.18, 'Contraindications': 'Avoid use if patient has coagulopathy or is receiving iodine compounds.', 'Patient_Population': 'Adult and Pediatric', 'Max_Operating_Temperature_C': 37.0, 'Device_Class': 'Class I', 'Regulatory_Approval_ID': 'P348923', 'Device_Lifetime_Years': 8.0, 'Manual_Version': 'v15.8'}, {'Indications_for_Use': 'Used for therapeutic drug delivery in neonatal patients requiring wound debridement.', 'Manual_Version': 'v6.7', 'Number_of_Cautions': 28, 'Patient_Population': 'Infant (0-2)', 'Regulatory_Approval_ID': 'BLA631713', 'Contraindications': 'Avoid use in patients with mesh implants or mesh implants. Not suitable for infectious disease isolation.', 'Model_Number': 'BIO146', 'Publication_Date': '2015-05-02', 'Device_Name': 'Surgical Robot', 'Device_Lifetime_Years': 11.0, 'combined_text': 'Device Name: Surgical Robot. Model: BIO146. Manufacturer: BioMérieux. Indications: Used for therapeutic drug delivery in neonatal patients requiring wound debridement.. Contraindications: Avoid use in patients with mesh implants or mesh implants. Not suitable for infectious disease isolation.', 'Number_of_Warnings': 22, 'Manufacturer': 'BioMérieux', 'Max_Operating_Temperature_C': 38.0, 'Device_Class': 'Class III'}, {'Device_Lifetime_Years': 11.0, 'Device_Class': 'Class I', 'Manufacturer': 'Edwards Lifesciences', 'Manual_Version': 'Rev. 3.2', 'Device_Name': 'Anesthesia Machine', 'Number_of_Cautions': 30, 'Contraindications': 'Avoid use in patients with active hepatic dysfunction or compromised respiratory function.', 'Publication_Date': '2017-05-06', 'Regulatory_Approval_ID': 'IVDR-159944', 'Indications_for_Use': 'Used for intraoperative sterilization monitoring during complex oncological surgeries.', 'Sterilization_Method': 'Steam Sterilization', 'Model_Number': 'C-1766', 'Device_Weight_kg': 37.87, 'Max_Operating_Temperature_C': 34.0, 'Number_of_Warnings': 9, 'Patient_Population': 'Geriatric', 'combined_text': 'Device Name: Anesthesia Machine. Model: C-1766. Manufacturer: Edwards Lifesciences. Indications: Used for intraoperative sterilization monitoring during complex oncological surgeries.. Contraindications: Avoid use in patients with active hepatic dysfunction or compromised respiratory function.'}]], 'distances': [[0.9251278638839722, 0.9255565404891968, 0.9680476188659668]]}

# %% [markdown]
# ## Setup Web Search

# %%
from langchain_tavily import TavilySearch

tavily_search = TavilySearch(topic="general", max_results=3)

query = 'What is speciality of dunkirk'

result = tavily_search.invoke({"query": query})

result['results'][1]['content']
# Out:
# '**Dunkirk** (UK: /dʌnˈkɜːrk/ *dun-KURK*; US: /ˈdʌnkɜːrk/ *DUN-kurk*; French: *Dunkerque*  ⓘ; Picard: *Dunkèke*; West Flemish: *Duunkerke*; Dutch: *Duinkerke* or *Duinkerken*) is a major port city in the department of Nord "Nord (French department)") in northern France. In the late 13th century, when the Dampierre count Guy of Flanders entered into the Franco-Flemish War "Franco-Flemish War (1297–1305)") against his suzerain King Philippe IV of France, the citizens of Dunkirk sided with the French against their count, who at first was defeated at the 1297 Battle of Furnes, but reached *de facto* autonomy upon the victorious Battle of the Golden Spurs five years later and exacted vengeance. Guy\'s son, Count Robert III (1305–1322), nevertheless granted further city rights to Dunkirk; his successor Count Louis I (1322–1346) had to face the Peasant revolt of 1323–1328, which was crushed by King Philippe VI of France at the 1328 Battle of Cassel "Battle of Cassel (1328)"), whereafter the Dunkirkers again were affected by the repressive measures of the French king. **^** "French city of Dunkirk tests out free transport – and it works".'

# %% [markdown]
# ## Setup OpenAI API - Models

# %%
from langchain_core.tools import tool

from openai import OpenAI

def get_llm_response(prompt: str) -> str:
    """Function to get response from LLM"""
    from openai import OpenAI
    client_llm = OpenAI(api_key=openai_api_key)
    response = client_llm.chat.completions.create(
        model="gpt-5-nano",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

prompt = "What is speciality of dunkirk"
response = get_llm_response(prompt)

# %%
print(response)
# Out:
# Do you mean Dunkirk (Dunkerque) in northern France, or something else named Dunkirk?
#
# If you mean the city, its main “specialties” are:
# - It’s a major North Sea port with a long maritime and industrial heritage.
# - The Dunkirk evacuation in 1940 (Operation Dynamo) is its most famous historical event, when hundreds of thousands of Allied troops were evacuated from the beaches under heavy fire. It’s also associated with the idea of the “Dunkirk spirit” of resilience and solidarity.
# - The beaches at Malo-les-Bains and the surrounding coastal area are well known for tourism and seaside culture.
# - The port area includes significant energy and ship/industrial infrastructure (for example, LNG facilities near the harbour).
#
# If you meant something else (a dish, a film, or another Dunkirk), tell me and I’ll tailor the answer.

# %% [markdown]
# # Build the Pipeline

# %%
from langgraph.graph import StateGraph, MessagesState, START, END

def retrieve_context_q_n_a(state):
    """Retrieve top documents from ChromaDB Collection 1 (Medical Q&A Data) based on query."""
    print("---RETRIEVING CONTEXT---")
    query = state["query"] 
    results = collection1.query(query_texts=[query], n_results=3)
    context = "\n".join(results["documents"][0])
    state["context"] = context
    state["source"] = "Medical Q&A Collection"
    print(context)
    
    return state

def retrieve_context_medical_device(state):
    """Retrieve top documents from ChromaDB Collection 2 (Medical Device Manuals Data) based on query."""
    query = state['query']
    results = collection2.query(query_texts=[query], n_results=3)
    context = "\n".join(results["documents"][0])
    state["context"] = context
    state["source"] = "Medical Device Manual"
    print(context)
    
    return state

def tavily_web_search(state):
    """Perform web search using the Tavily Search API."""
    print("--- Performing Tavily Web Search ---")
    tavily_search = TavilySearch(topic="general", max_results=1)
    query = state['query']
    result_ = tavily_search.invoke({"query": query})
    state["context"] = result_['results'][0]['content']

    return state


def router(state: GraphState) -> Literal[
    "Retrieve_QnA", "Retrieve_Device", "Web_Search"
]:
    """Agentic router: decides which retrieval method to use."""
    query = state["query"]

    # A lightweight decision LLM — you can replace this with GPT-4o-mini, etc.
    decision_prompt = f"""
    You are a routing agent. Based on the user query, decide where to look for information.

    Options:
    - Retrieve_QnA: if it's about general medical knowledge, symptoms, or treatment.
    - Retrieve_Device: if it's about medical devices, manuals, or instructions.
    - Web_Search: if it's about recent news, brand names, or external data.

    Query: "{query}"

    Respond ONLY with one of: Retrieve_QnA, Retrieve_Device, Web_Search
    """

    router_decision = get_llm_response(decision_prompt).strip()
    print(f"---ROUTER DECISION: {router_decision}---")

    print(router_decision)

    state["source"] = router_decision
    
    return state

def route_decision(state: GraphState) -> str:
    return state["source"]


def check_context_relevance(state: GraphState):
    """Determine whether the retrieved context is relevant or not."""
    print("---CONTEXT RELEVANCE CHECKER---")
    query = state["query"]
    context = state["context"]

    relevance_prompt = f"""
    Check the context below to see if the context is relevant to the user query or not.
    ####
    Context:
    {context}
    ####
    User Query: {query}

    Options:
    - Yes: if the context is relevant.
    - No: if the context is not relevant.

    Please answer with only 'Yes' or 'No'.
    """
    relevance_decision_value = get_llm_response(relevance_prompt).strip()
    print(f"---RELEVANCE DECISION: {relevance_decision_value}---")
    state["is_relevant"] = relevance_decision_value

    return state


def relevance_decision(state: GraphState) -> str:
    iteration_count = state.get("iteration_count", 0)
    iteration_count += 1
    state["iteration_count"] = iteration_count
    ## Limiting to max 3 iterations
    if iteration_count >= 3:
        print("---MAX ITERATIONS REACHED, FORCING 'Yes'---")
        state["is_relevant"] = "Yes"
    return state["is_relevant"]



def build_prompt(state):
    """Construct the RAG-style prompt."""
    print("---AUGMENT (BUILDING GENERATIVE PROMPT)---")
    query = state["query"]
    context = state["context"]

    prompt = f"""
    Answer the following question using the context below.
    Context:
    {context}
    Question: {query}
    please limit your answer in 50 words.
    """
    
    state["prompt"] = prompt
    print(prompt)
    return state

def call_llm(state):
    """Call your existing LLM function."""
    print("---GENERATE (CALLING LLM)---")
    prompt = state["prompt"]
    answer = get_llm_response(prompt)
    state["response"] = answer
    return state

# %% [markdown]
# ## Define state graph

# %%
class GraphState(TypedDict):
    query: str
    context: str
    prompt: str
    response: str
    source: str 
    is_relevant: str
    iteration_count: str

workflow = StateGraph(GraphState)

workflow.add_node("Router", router)
workflow.add_node("Retrieve_QnA", retrieve_context_q_n_a)
workflow.add_node("Retrieve_Device", retrieve_context_medical_device)
workflow.add_node("Web_Search", tavily_web_search)
workflow.add_node("Relevance_Checker", check_context_relevance)
workflow.add_node("Augment", build_prompt)
workflow.add_node("Generate", call_llm)

workflow.add_edge(START, "Router")
workflow.add_conditional_edges(
    "Router",
    route_decision, 
    {
        "Retrieve_QnA": "Retrieve_QnA",
        "Retrieve_Device": "Retrieve_Device",
        "Web_Search": "Web_Search",
    }
)
workflow.add_edge("Retrieve_QnA", "Relevance_Checker")
workflow.add_edge("Retrieve_Device", "Relevance_Checker")
workflow.add_edge("Web_Search", "Relevance_Checker")
workflow.add_conditional_edges(
    "Relevance_Checker",
    relevance_decision,  
    {
        "Yes": "Augment",
        "No": "Web_Search",
    }
)
workflow.add_edge("Augment", "Generate")
workflow.add_edge("Generate", END)

agentic_rag = workflow.compile()

# %% [markdown]
# ## Visualize state graph

# %%
from IPython.display import Image, display
display(Image(agentic_rag.get_graph().draw_mermaid_png()))

# %% [markdown]
# # Test the Agentic RAG pipeline

# %%
input_state = {"query": "what is the treatment for down's symdrome"}

from pprint import pprint
for step in agentic_rag.stream(input_state):
    for key, value in step.items():
        pprint(f"Finished running {key}:")
pprint(value["response"])
# Out:
# ---ROUTER DECISION: Retrieve_QnA---
# Retrieve_QnA
# 'Finished running Router:'
# ---RETRIEVING CONTEXT---
# Question: What are the treatments for Antisynthetase syndrome ?. Answer: What treatment is available for antisynthetase syndrome? Corticosteroids are typically the first-line of treatment and may be required for several months or years. These medications are often given orally; however, in severe cases, intravenous methylprednisolone may be prescribe initially. Immunosuppressive medications may also be recommended, especially in people with severe muscle weakness or symptomatic interstitial lung disease. Physical therapy is often necessary to improve weakness, reduce further muscle wasting from disuse, and prevent muscle contractures.. Type: treatment.
# Question: What are the treatments for Orthostatic Hypotension ?. Answer: When orthostatic hypotension is caused by hypovolemia due to medications, the disorder may be reversed by adjusting the dosage or by discontinuing the medication. When the condition is caused by prolonged bed rest, improvement may occur by sitting up with increasing frequency each day. In some cases, physical counterpressure such as elastic hose or whole-body inflatable suits may be required. Dehydration is treated with salt and fluids. More severe cases can be treated with drugs, such as midodrine, to raise blood pressure.. Type: treatment.
# Question: What are the treatments for Wiskott-Aldrich syndrome ?. Answer: These resources address the diagnosis or management of Wiskott-Aldrich syndrome:  - Gene Review: Gene Review: WAS-Related Disorders  - Genetic Testing Registry: Wiskott-Aldrich syndrome  - MedlinePlus Encyclopedia: Thrombocytopenia  - National Marrow Donor Program  - Rare Disease Clinical Research Network: Primary Immune Deficiency Treatment Consortium   These resources from MedlinePlus offer information about the diagnosis and management of various health conditions:  - Diagnostic Tests  - Drug Therapy  - Surgery and Rehabilitation  - Genetic Counseling   - Palliative Care. Type: treatment.
# 'Finished running Retrieve_QnA:'
# ---CONTEXT RELEVANCE CHECKER---
# ---RELEVANCE DECISION: No---
# 'Finished running Relevance_Checker:'
# --- Performing Tavily Web Search ---
# 'Finished running Web_Search:'
# ---CONTEXT RELEVANCE CHECKER---
# ---RELEVANCE DECISION: Yes---
# 'Finished running Relevance_Checker:'
# ---AUGMENT (BUILDING GENERATIVE PROMPT)---
#
#     Answer the following question using the context below.
#     Context:
#     While there is no one-size-fits-all solution, a combination of therapeutic interventions, early educational support, and collaborative care can significantly impact the quality of life for individuals with Down syndrome. The journey toward maximizing the potential of individuals with Down syndrome begins with early intervention and tailored educational therapies. Many individuals with Down syndrome will work with a physical therapist for many years to address their motor skills and physical abilities. Speech-language therapy plays a pivotal role in breaking down communication barriers for individuals with Down syndrome. Communication can be an ongoing challenge, and many individuals with Down syndrome will benefit from having access to speech language therapy in a school setting as well as later in life.
#     Question: what is the treatment for down's symdrome
#     please limit your answer in 50 words.
#
# 'Finished running Augment:'
# ---GENERATE (CALLING LLM)---
# 'Finished running Generate:'
# ('There is no single cure or one-size-fits-all treatment for Down syndrome. '
#  'Management focuses on early intervention and individualized plans, including '
#  'physical therapy to improve motor skills and fitness, and speech-language '
#  'therapy to enhance communication, along with educational support and '
#  'multidisciplinary care.')

# %%
input_state = {"query": "what was the company created the first vaccine for COVID-19"}

from pprint import pprint
for step in agentic_rag.stream(input_state):
    for key, value in step.items():
        pprint(f"Finished running {key}:")
pprint(value["response"])
# Out:
# ---ROUTER DECISION: Web_Search---
# Web_Search
# 'Finished running Router:'
# --- Performing Tavily Web Search ---
# 'Finished running Web_Search:'
# ---CONTEXT RELEVANCE CHECKER---
# ---RELEVANCE DECISION: Yes---
# 'Finished running Relevance_Checker:'
# ---AUGMENT (BUILDING GENERATIVE PROMPT)---
#
#     Answer the following question using the context below.
#     Context:
#     The Pfizer and Moderna COVID-19 vaccines were the first mRNA vaccines that humans received outside of clinical trials. Dr. Thomas Kenyon, chief
#     Question: what was the company created the first vaccine for COVID-19
#     please limit your answer in 50 words.
#
# 'Finished running Augment:'
# ---GENERATE (CALLING LLM)---
# 'Finished running Generate:'
# ('Pfizer, in collaboration with BioNTech, created and obtained authorization '
#  'for the first COVID-19 vaccine (Comirnaty).')
